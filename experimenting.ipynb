# %%
from dataset import load_data
import torch
import utils
import models
import train as t
import const

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
train_data, val_data, test_data = load_data()

# %%
inputs, classes = next(iter(train_data))
utils.show_databatch(inputs, classes)

# %%
vgg = models.baseline()
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /home/madeleineyip/.cache/torch/checkpoints/vgg16-397923af.pth
# 100%|██████████| 553433881/553433881 [00:27<00:00, 20271159.02it/s]

# %%
print (const.PROTOFILE)
# Out:
# utils/residual-attention-network/imagenet_model/AttentionNeXt-56-deploy.prototxt
